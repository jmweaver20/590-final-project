# %% [markdown]
# ## Plotted Results
# Once you have consilidated all of your survey shares and ran the `script.py` file, you can see the outcomes of across surveys in this notebook!

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from gen_plots import generate_plot, generate_gender_counts, generate_majors

# %% [markdown]
# ## Students Across Gender

# %%
generate_gender_counts()

# %% [markdown]
# ## `comp_majors`
#
# Who da majors

# %%
generate_majors()

# %% [markdown]
# ## `comp_professors`
# The `comp_professors` category evaulates the level of comfort students have with professors in the computer science department.

# %%
generate_plot("comp_professors")

# %% [markdown]
# ## `wellness`
# The `wellness` category evaulates the general happiness and wellness of students.

# %%
generate_plot("wellness")

# %% [markdown]
# ## `comp_comfortability`
# The `comp_comfortability` category evaulates how comfortable students feel within their the computer science classes.

# %%
generate_plot("comp_comfortability")

# %% [markdown]
# ## `course_performance`
# The `course_performance` category evaulates how well students percieve they are doing within their courses.

# %%
generate_plot("course_performance")

# %% [markdown]
# ## `gpa`
# The `gpa` category evaulates a student's Grade Point Average.

# %%
generate_plot("gpa")
